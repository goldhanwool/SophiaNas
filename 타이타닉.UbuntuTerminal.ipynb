# %% [markdown]
# ## 타이타닉 탑승객 남녀 숫자 카운팅

# %% [markdown]
# ~/다운로드: tail -n +2 titanic.csv | cut -d ',' -f 5 | sort -n | uniq -c

# %% [markdown]
# # Brown 성을 가진 승객 구하기

# %% [markdown]
# ~/다운로드: titan
