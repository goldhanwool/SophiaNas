# %% [markdown]
# # 안녕하세요

# %% [markdown]
# --------------------

# %% [markdown]
# *여기가 개발자들의 핫플레이스 깃허브인가요*

# %% [markdown]
# *저는 현재 어플리케이션 기획자로 재직 중인 김영록입니다.*

# %% [markdown]
# *고전텍스트(고전철학, 문학)에 대한 집단 번역과 토론을 위한 플랫폼을 창업했었고 2년 넘게 제작, 운영하다가
# ~~인성에 문제가 생겨~~ 잠시 평생프로젝트로 남겨놓고
# 어플리케이션 기획자로 취업하여 현업에서 다양한 프로젝트들을 진행했습니다.*

# %% [markdown]
# - 고전토론번역 플랫폼 소피아나스 / 고대 조로아스터경전 국내최초번역
# - 비트코인 쇼핑몰
# - 유전자 기반 맞춤형 식단, 운동 추천 app
# - 도보여행 플랫폼

# %% [markdown]
# 헬스케어 쪽에서 기획을 하다보니 개인별 건강데이터를 분석하고 활용하는데 있어 데이터 마이닝과 인공지능에 대한 이해가
# 꼭 필요하다는 것을 느끼고 지원하게 되었습니다. 만나서 진심으로 반갑고 좋은 연으로 이어가기를 바라겠습니다.
